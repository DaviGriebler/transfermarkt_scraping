# %%
import re
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
headers = {
    "User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:150.0) Gecko/20100101 Firefox/150.0"
}

# %%
# Scraping from url
url = "https://www.transfermarkt.com.br/premier-league/spieltag/wettbewerb/GB1/saison_id/2025/spieltag/34"
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.content, "html.parser")
all_information = soup.find_all('table', {'style':'border-top: 0 !important;'})

# Gathering Useful Information
round_1 = []
for row in all_information:
    temp = []

    # List with the entire class necesaire to get the home and away team's names
    gross_home_team = row.find('td', {'class':'rechts hauptlink no-border-rechts hide-for-small spieltagsansicht-vereinsname'})
    gross_away_team = row.find('td', {'class':'hauptlink zentriert no-border-rechts no-border-links hide-for-small spieltagsansicht-wappen'})

    # Checking for a possible forum buttom
    home_forum_check = gross_home_team.find('a').get('href')
    away_forum_check = gross_away_team.find('a').get('href')

    # Different ways to get the title depending if it has the forum buttom
    if 'forum' in home_forum_check and 'forum' in away_forum_check:
        home_team = gross_home_team.find_all('a')[1].get('title')
        away_team = gross_away_team.find_all('a')[1].get('title')
    elif 'forum' in home_forum_check:
        home_team = gross_home_team.find_all('a')[1].get('title')
        away_team = gross_away_team.find('a').get('title')
    elif 'forum' in away_forum_check:
        home_team = gross_home_team.find('a').get('title')
        way_team = gross_away_team.find_all('a')[1].get('title')
    else:
        home_team = gross_home_team.find('a').get('title')
        away_team = gross_away_team.find('a').get('title')

    # Getting the final score
    final_score = row.find('span', {'class':'matchresult finished'}).string

    # Appending data from a single match together
    temp.append(home_team)
    temp.append(final_score)
    temp.append(away_team)

    # Storing adicional info separately, easier to extract right information
    adicional_info = row.find_all('td', {'class':'zentriert no-border'})

    for i, item in enumerate(adicional_info):
        if i == 2:
            text = item.get_text(" ", strip=True)
            try: 
                attendance= text.split()[0]
                temp.append(attendance.strip())
            except: temp.append(text)
        else:
            day_ref = item.find('a').string
            temp.append(day_ref.strip())

    round_1.append(temp)

# Transforming in a Data Frame
df_round_1 = pd.DataFrame(round_1)
df_round_1.columns = ['home_team','score','away_team','date','referee','attendance']
display(df_round_1)
# Out:
#                  home_team score           away_team        date  \
# 0   Brighton & Hove Albion   3:0          Chelsea FC  21/04/2026
# 1          AFC Bournemouth   2:2    Leeds United FC   22/04/2026
# 2               FC Burnley   0:1  Manchester City FC  22/04/2026
# 3           AFC Sunderland   0:5   Nottingham Forest  24/04/2026
# 4                FC Fulham   1:0      Aston Villa FC  25/04/2026
# 5             FC Liverpool   3:1   Crystal Palace FC  25/04/2026
# 6          West Ham United   2:1          FC Everton  25/04/2026
# 7  Wolverhampton Wanderers   0:1  Tottenham Hotspur   25/04/2026
# 8               FC Arsenal   1:0    Newcastle United  25/04/2026
# 9     Manchester United FC   2:1        Brentford FC  27/04/2026
#
#              referee attendance
# 0       Craig Pawson     31.220
# 1  Michael Salisbury     11.226
# 2      Andrew Madley     21.259
# 3     Darren England
# 4     Michael Oliver     27.606
# 5      Andrew Madley     60.314
# 6     Stuart Attwell     62.454
# 7     Anthony Taylor     31.253
# 8     Samuel Barrott     60.204
# 9     Chris Kavanagh     73.773

# %%
all_rounds = []
for n_round in range(1,39):
    # Scraping from url
    url = f"https://www.transfermarkt.com.br/premier-league/spieltag/wettbewerb/GB1/saison_id/2025/spieltag/{n_round}"
    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.content, "html.parser")
    all_information = soup.find_all('table', {'style':'border-top: 0 !important;'})

    # Gathering Useful Information
    for row in all_information:
        temp = []

        # Setting Keys
        season_key = 'PL-2025'
        if n_round < 10: round_key = 'R-2025-0' + str(n_round)
        else: round_key = 'R-2025-' + str(n_round)
        
        temp.append(season_key)
        temp.append(round_key)

        # List with the entire class necesaire to get the home and away team's names
        gross_home_team = row.find('td', {'class':'rechts hauptlink no-border-rechts hide-for-small spieltagsansicht-vereinsname'})
        gross_away_team = row.find('td', {'class':'hauptlink zentriert no-border-rechts no-border-links hide-for-small spieltagsansicht-wappen'})

        # Checking for a possible forum buttom
        home_forum_check = gross_home_team.find('a').get('href')
        away_forum_check = gross_away_team.find('a').get('href')

        # Different ways to get the title depending if it has the forum buttom
        if 'forum' in home_forum_check and 'forum' in away_forum_check:
            home_team = gross_home_team.find_all('a')[1].get('title')
            away_team = gross_away_team.find_all('a')[1].get('title')
        elif 'forum' in home_forum_check:
            home_team = gross_home_team.find_all('a')[1].get('title')
            away_team = gross_away_team.find('a').get('title')
        elif 'forum' in away_forum_check:
            home_team = gross_home_team.find('a').get('title')
            away_team = gross_away_team.find_all('a')[1].get('title')
        else:
            home_team = gross_home_team.find('a').get('title')
            away_team = gross_away_team.find('a').get('title')

        # Getting the final score
        final_score = row.find('span', {'class':'matchresult finished'}).string

        # Appending data from a single match together
        temp.append(home_team)
        temp.append(final_score)
        temp.append(away_team)

        # Storing adicional info separately, easier to extract right information
        adicional_info = row.find_all('td', {'class':'zentriert no-border'})

        for i, item in enumerate(adicional_info):
            if i == 2:
                text = item.get_text(" ", strip=True)
                try: 
                    attendance = text.split()[0]
                    temp.append(attendance)
                except: temp.append(text)
            else:
                day_ref = item.find('a').string
                temp.append(day_ref.strip())

        all_rounds.append(temp)

df_all_rounds = pd.DataFrame(all_rounds)
df_all_rounds.columns = ['season_id','round_id', 'home_team', 'final_score', 'away_team', 'date', 'referee', 'attendance']
display(df_all_rounds)
# Out:
#     season_id   round_id               home_team final_score  \
# 0     PL-2025  R-2025-01            FC Liverpool         4:2
# 1     PL-2025  R-2025-01          Aston Villa FC         0:0
# 2     PL-2025  R-2025-01  Brighton & Hove Albion         1:1
# 3     PL-2025  R-2025-01          AFC Sunderland         3:0
# 4     PL-2025  R-2025-01      Tottenham Hotspur          3:0
# ..        ...        ...                     ...         ...
# 375   PL-2025  R-2025-38      Manchester City FC         1:2
# 376   PL-2025  R-2025-38       Nottingham Forest         1:1
# 377   PL-2025  R-2025-38          AFC Sunderland         2:1
# 378   PL-2025  R-2025-38      Tottenham Hotspur          1:0
# 379   PL-2025  R-2025-38         West Ham United         3:0
#
#             away_team        date         referee attendance
# 0     AFC Bournemouth  15/08/2025  Anthony Taylor     60.315
# 1    Newcastle United  16/08/2025    Craig Pawson     42.526
# 2           FC Fulham  16/08/2025  Samuel Barrott     31.478
# 3     West Ham United  16/08/2025    Robert Jones     46.233
# 4          FC Burnley  16/08/2025  Michael Oliver     61.077
# ..                ...         ...             ...        ...
# 375    Aston Villa FC  24/05/2026   Andrew Madley     60.332
# 376   AFC Bournemouth  24/05/2026    Craig Pawson     30.741
# 377        Chelsea FC  24/05/2026  Chris Kavanagh
# 378        FC Everton  24/05/2026  Michael Oliver     61.812
# 379  Leeds United FC   24/05/2026  Anthony Taylor     62.471
#
# [380 rows x 8 columns]
