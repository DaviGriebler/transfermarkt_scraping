# %%
import re
import requests
from bs4 import BeautifulSoup

# %%
url = "https://www.transfermarkt.com.br/premier-league/tabelle/wettbewerb/GB1/saison_id/2025#google_vignette"

headers = {
    "User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:150.0) Gecko/20100101 Firefox/150.0"
}

response = requests.get(url, headers=headers)

response.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(response.content, "html.parser")

# %%
rows = soup.select("tbody tr")

data = []

for row in rows:
    team_tag = row.select_one("td.hauptlink a")
    
    if not team_tag:
        continue  # skip empty/header rows
    
    team_name = team_tag.get("title")
    
    stats = row.select("td.zentriert")
    stats_text = [s.get_text(strip=True) for s in stats]
    
    data.append([team_name] + stats_text)

print(data)
# Out:
# [['FC Arsenal', '', '34', '22', '7', '5', '64:26', '38', '73'], ['Manchester City FC', '', '33', '21', '7', '5', '66:29', '37', '70'], ['Manchester United FC', '', '34', '17', '10', '7', '60:46', '14', '61'], ['FC Liverpool', '', '34', '17', '7', '10', '57:44', '13', '58'], ['Aston Villa FC', '', '34', '17', '7', '10', '47:42', '5', '58'], ['Brighton & Hove Albion', '', '34', '13', '11', '10', '48:39', '9', '50'], ['AFC Bournemouth', '', '34', '11', '16', '7', '52:52', '0', '49'], ['Chelsea FC', '', '34', '13', '9', '12', '53:45', '8', '48'], ['Brentford FC', '', '34', '13', '9', '12', '49:46', '3', '48'], ['FC Fulham', '', '34', '14', '6', '14', '44:46', '-2', '48'], ['FC Everton', '', '34', '13', '8', '13', '41:41', '0', '47'], ['AFC Sunderland', '', '34', '12', '10', '12', '36:45', '-9', '46'], ['Crystal Palace FC', '', '33', '11', '10', '12', '36:39', '-3', '43'], ['Newcastle United', '', '34', '12', '6', '16', '46:50', '-4', '42'], ['Leeds United FC ', '', '34', '9', '13', '12',
# ...
