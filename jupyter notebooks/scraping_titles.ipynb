# %%
import re
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
headers = {
    "User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:150.0) Gecko/20100101 Firefox/150.0"
}

# %%
titles = []

url = "https://www.transfermarkt.com.br/premier-league/erfolge/wettbewerb/GB1"
response = requests.get(url, headers=headers)
response.status_code
soup = BeautifulSoup(response.content, "html.parser")

all_info = soup.find_all('tbody')
info = all_info[0].find_all('tr')


for row in info:
    temp = []

    season = row.find('td', {'class':'zentriert'}).string
    if season == '91/92': break # First season of the current format of the Premier League
    
    team_manager = row.find_all('a')

    temp.append(season)

    for i, item in enumerate(team_manager):
        if i == 0: continue
        temp.append(item.string)
    
    titles.append(temp)

df_titles = pd.DataFrame(titles)
df_titles.columns = ['season_name', 'team_name', 'manager_name']
display(df_titles)
# Out:
#    season_name             team_name       manager_name
# 0        25/26            FC Arsenal       Mikel Arteta
# 1        24/25          FC Liverpool          Arne Slot
# 2        23/24    Manchester City FC      Pep Guardiola
# 3        22/23    Manchester City FC      Pep Guardiola
# 4        21/22    Manchester City FC      Pep Guardiola
# 5        20/21    Manchester City FC      Pep Guardiola
# 6        19/20          FC Liverpool       Jürgen Klopp
# 7        18/19    Manchester City FC      Pep Guardiola
# 8        17/18    Manchester City FC      Pep Guardiola
# 9        16/17            Chelsea FC      Antonio Conte
# 10       15/16     Leicester City FC    Claudio Ranieri
# 11       14/15            Chelsea FC      José Mourinho
# 12       13/14    Manchester City FC  Manuel Pellegrini
# 13       12/13  Manchester United FC      Alex Ferguson
# 14       11/12    Manchester City FC    Roberto Mancini
# 15       10/11  Manchester United FC      Alex Ferguson
# 16       09/10            Chelsea FC    Carlo Ancelotti
# 17       08/09  Manchester United FC      Alex Ferguson
# 18       07/08  Manchester United FC      Alex Ferguson
# 19       06/07  Manchester United FC      Alex Ferguson
# 20       05/06            Chelsea FC      José Mourinho
# 21       04/05            Chelsea FC      José Mourinho
# 22       03/04            FC Arsenal      Arsène Wenger
# 23       02/03  Manchester United FC      Alex Ferguson
# 24       01/02            FC Arsenal      Arsène Wenger
# 25       00/01  Manchester United FC      Alex Ferguson
# 26       99/00  Manchester United FC      Alex Ferguson
# 27       98/99  Manchester United FC      Alex Ferguson
# 28       97/98            FC Arsenal      Arsène Wenger
# 29       96/97  Manchester United FC      Alex Ferguson
# 30       95/96  Manchester United FC      Alex Ferguson
# 31       94/95      Blackburn Rovers     Kenny Dalglish
# 32       93/94  Manchester United FC      Alex Ferguson
# 33       92/93  Manchester United FC      Alex Ferguson
